# %%
import os
import re
import io
import nltk
import string
import math
from pycontractions import Contractions

# %%
os.chdir('C:/Users/Vedant/Desktop/NLP LAB/N-gram dataset/')

# %%
pat = 'C:/Users/Vedant/Desktop/NLP LAB/N-gram dataset/'

# %%
Data = []

# %%
for y in range(4,7):
    path = os.path.join(pat,'200'+ str(y))
    os.chdir(path)
    for filename in os.listdir():
        f=0
        with io.open(filename,'r') as f:
            file = f.read()
        if 'index' not in filename:
            for st in re.split('\n',file):
                if '200'+str(y) in st:
                    f=1
                    continue
                if not (st == '' or st[0] == '<'):
                    if f == 1:
                        Data.append(st)
        else:
            for st in re.split('\n',file):
                if '1999' in st:
                    f=1
                    continue
                if not (st == '' or st[0] == '<'):
                    if f == 1:
                        Data.append(st)

# %%
test = []

# %%
y = 7
path = os.path.join(pat,'200'+ str(y))
os.chdir(path)
for filename in os.listdir():
    f=0
    with io.open(filename,'r') as f:
        file = f.read()
    if 'index' not in filename:
        for st in re.split('\n',file):
            if '200'+str(y) in st:
                f=1
                continue
            if not (st == '' or st[0] == '<'):
                if f == 1:
                    test.append(st)
    else:
        for st in re.split('\n',file):
            if '1999' in st:
                f=1
                continue
            if not (st == '' or st[0] == '<'):
                if f == 1:
                    test.append(st)

# %%
UNK = None

# %%
class UnigramLanguageModel:
    def __init__(self, sentences, smoothing=False):
        self.unigram_frequencies = dict()
        self.corpus_length = 0
        for sentence in sentences:
            for word in sentence:
                self.unigram_frequencies[word] = self.unigram_frequencies.get(word, 0) + 1
                self.corpus_length += 1
        self.unique_words = len(self.unigram_frequencies)
        self.smoothing = smoothing

    def calculate_unigram_probability(self, word):
            word_probability_numerator = self.unigram_frequencies.get(word, 0)
            word_probability_denominator = self.corpus_length
            if self.smoothing:
                word_probability_numerator += 1
                word_probability_denominator += self.unique_words + 1
            return float(word_probability_numerator) / float(word_probability_denominator)

    def calculate_sentence_probability(self, sentence, normalize_probability=True):
        sentence_probability_log_sum = 0
        for word in sentence:
            word_probability = self.calculate_unigram_probability(word)
            sentence_probability_log_sum += math.log(word_probability, 2)
        return math.pow(2, sentence_probability_log_sum) if normalize_probability else sentence_probability_log_sum                

    def sorted_vocabulary(self):
        full_vocab = list(self.unigram_frequencies.keys())
        full_vocab.sort()
        full_vocab.append(UNK)
        return full_vocab
    
class BigramLanguageModel(UnigramLanguageModel):
    def __init__(self, sentences, smoothing=False):
        UnigramLanguageModel.__init__(self, sentences, smoothing)
        self.bigram_frequencies = dict()
        self.unique_bigrams = set()
        for sentence in sentences:
            previous_word = None
            for word in sentence:
                if previous_word != None:
                    self.bigram_frequencies[(previous_word, word)] = self.bigram_frequencies.get((previous_word, word),0) + 1
                    self.unique_bigrams.add((previous_word, word))
                previous_word = word
        self.unique__bigram_words = len(self.unigram_frequencies)

    def calculate_bigram_probabilty(self, previous_word, word):
        bigram_word_probability_numerator = self.bigram_frequencies.get((previous_word, word), 0)
        bigram_word_probability_denominator = self.unigram_frequencies.get(previous_word, 0)
        if self.smoothing:
            bigram_word_probability_numerator += 1
            bigram_word_probability_denominator += self.unique__bigram_words
        if bigram_word_probability_numerator == 0 or bigram_word_probability_denominator == 0:
            return 0.0
        else:
            return float(bigram_word_probability_numerator) / float(bigram_word_probability_denominator)

    def calculate_bigram_sentence_probability(self, sentence, normalize_probability=True):
        bigram_sentence_probability_log_sum = 0
        previous_word = None
        for word in sentence:
            if previous_word != None:
                bigram_word_probability = self.calculate_bigram_probabilty(previous_word, word)
                bigram_sentence_probability_log_sum += math.log(bigram_word_probability, 2)
            previous_word = word
        return math.pow(2,bigram_sentence_probability_log_sum) if normalize_probability else bigram_sentence_probability_log_sum

class TrigramLanguageModel(BigramLanguageModel):
    def __init__(self,sentences,smoothing = False):
        BigramLanguageModel.__init__(self, sentences, smoothing)
        self.trigram_frequencies = dict()
        self.unique_trigrams = set()
        for sentence in sentences:
            first_word = None
            second_word = None
            for word in sentence:
                if second_word != None and first_word != None:
                    self.trigram_frequencies[(second_word,first_word, word)] = self.trigram_frequencies.get((second_word,first_word, word),0) + 1
                    self.unique_trigrams.add((second_word,first_word, word))
                second_word = first_word
                first_word = word
        self.unique__trigram_words = len(self.unigram_frequencies)
    def calculate_trigram_probabilty(self,second_word,first_word,word):
        trigram_word_probability_numerator = self.trigram_frequencies.get((second_word,first_word, word), 0)
        trigram_word_probability_denominator = self.bigram_frequencies.get((second_word,first_word), 0)
        if self.smoothing:
            trigram_word_probability_numerator += 1
            trigram_word_probability_denominator += self.unique__trigram_words
        return 0.0 if trigram_word_probability_numerator == 0 or trigram_word_probability_denominator == 0 else float(
            trigram_word_probability_numerator) / float(trigram_word_probability_denominator)

    def calculate_trigram_sentence_probability(self, sentence, normalize_probability=True):
        trigram_sentence_probability_log_sum = 0
        second_word = None
        first_word = None
        
        for word in sentence:
            if second_word != None and first_word != None:
                trigram_word_probability = self.calculate_trigram_probabilty(second_word,first_word, word)
                trigram_sentence_probability_log_sum += math.log(trigram_word_probability, 2)
            first_word = word
            second_word = first_word
        return math.pow(2,
                        trigram_sentence_probability_log_sum) if normalize_probability else trigram_sentence_probability_log_sum

    
def calculate_number_of_unigrams(sentences):
    unigram_count = 0
    for sentence in sentences:
        unigram_count += len(sentence)
    return unigram_count
def calculate_number_of_bigrams(sentences):
        bigram_count = 0
        for sentence in sentences:
            bigram_count += len(sentence) - 1
        return bigram_count
def calculate_number_of_trigrams(sentences):
        trigram_count = 0
        for sentence in sentences:
            trigram_count += len(sentence) - 2
        return trigram_count
def calculate_unigram_perplexity(model, sentences):
    unigram_count = calculate_number_of_unigrams(sentences)
    sentence_probability_log_sum = 0
    for sentence in sentences:
        try:
            sentence_probability_log_sum -= math.log(model.calculate_sentence_probability(sentence), 2)
        except:
            pass
    return math.pow(2, sentence_probability_log_sum / unigram_count)

def calculate_bigram_perplexity(model, sentences):
    number_of_bigrams = calculate_number_of_bigrams(sentences)
    bigram_sentence_probability_log_sum = 0
    for sentence in sentences:
        try:
            bigram_sentence_probability_log_sum -= math.log(model.calculate_bigram_sentence_probability(sentence), 2)
        except:
            pass
    return math.pow(2, bigram_sentence_probability_log_sum / number_of_bigrams)

def calculate_trigram_perplexity(model, sentences):
    number_of_trigrams = calculate_number_of_trigrams(sentences)
    trigram_sentence_probability_log_sum = 0
    for sentence in sentences:
        try:
            trigram_sentence_probability_log_sum -= math.log(model.calculate_trigram_sentence_probability(sentence), 2)
        except:
            pass
    return math.pow(2, trigram_sentence_probability_log_sum / number_of_trigrams)

# %%
from string import digits
remove_digits = str.maketrans('', '', digits)
from string import punctuation
table = str.maketrans('','',punctuation)
cont = Contractions(api_key="glove-twitter-100")

# %%
cont.load_models()

# %%
for d in range(len(Data)):
    s = Data[d]
    s = s.lower()
    s = s.translate(table)
    s = s.translate(remove_digits)
    s = list(cont.expand_texts([s]))[0]
    s = nltk.word_tokenize(s)
    Data[d] = s

# %%
dataset_model = TrigramLanguageModel(Data)

# %%
dataset_model_smoothed = TrigramLanguageModel(Data,smoothing = True)

# %%
sorted_vocab_keys = dataset_model.sorted_vocabulary()

# %%
print("== TRAIN PERPLEXITY == ")
print("unigram: ", calculate_unigram_perplexity(dataset_model, Data))
print("bigram: ", calculate_bigram_perplexity(dataset_model, Data))
print("trigram: ", calculate_trigram_perplexity(dataset_model, Data))
# Out:
# == TRAIN PERPLEXITY ==
# unigram:  1535.4401039431868
# bigram:  82.7156875550523
# trigram:  1.0000052122827534

# %%
print("== TRAIN PERPLEXITY == ")
print("unigram: ", calculate_unigram_perplexity(dataset_model_smoothed, Data))
print("bigram: ", calculate_bigram_perplexity(dataset_model_smoothed, Data))
print("trigram: ", calculate_trigram_perplexity(dataset_model_smoothed, Data))
# Out:
# == TRAIN PERPLEXITY ==
# unigram:  1545.508219559923
# bigram:  3416.6267911858044
# trigram:  40033.6378309513

# %%
for d in range(len(test)):
    s = test[d]
    s = s.lower()
    s = s.translate(table)
    s = s.translate(remove_digits)
    s = nltk.word_tokenize(s)
    test[d] = s

# %%
print("== TEST PERPLEXITY == ")
print("unigram: ", calculate_unigram_perplexity(dataset_model, test))
print("bigram: ", calculate_bigram_perplexity(dataset_model, test))
print("trigram: ", calculate_trigram_perplexity(dataset_model, test))
# Out:
# == TEST PERPLEXITY ==
# unigram:  98.70888683427059
# bigram:  1.0437204499672985
# trigram:  1.0000786856105486

# %%
print("== TEST PERPLEXITY == ")
print("unigram: ", calculate_unigram_perplexity(dataset_model_smoothed, test))
print("bigram: ", calculate_bigram_perplexity(dataset_model_smoothed, test))
print("trigram: ", calculate_trigram_perplexity(dataset_model_smoothed, test))
# Out:
# == TEST PERPLEXITY ==
# unigram:  1920.9823811109472
# bigram:  5247.631636500524
# trigram:  72673.97032516371

# %% [markdown]
# Trigram Language Model

# %%
dataset_model_smoothed = TrigramLanguageModel(test,smoothing = True)

# %%
sorted_vocab_keys = dataset_model_smoothed.sorted_vocabulary()

# %%
len(sorted_vocab_keys)
# Out:
# 8245

# %%
Least_probability = 1.0/float(dataset_model_smoothed.unique__bigram_words)

# %% [markdown]
# Sentence Generation : Trigram

# %%
sent = {}
for x in dataset_model_smoothed.trigram_frequencies.keys():
    if (x[0],x[1]) not in sent.keys():
        sent[(x[0],x[1])] = {}
    sent[(x[0],x[1])][x[2]] = float(dataset_model_smoothed.trigram_frequencies[(x[0],x[1],x[2])])/float(dataset_model_smoothed.bigram_frequencies[(x[0],x[1])])

# %%
for x in sent.keys():
    sent[x] = dict(sorted(sent[x].items(),key=lambda x: x[1]))

# %%
sent
# Out:
# {('saddam', 'hussein'): {'smoked': 0.1111111111111111,
#   'into': 0.1111111111111111,
#   'finally': 0.1111111111111111,
#   'last': 0.1111111111111111,
#   'in': 0.1111111111111111,
#   'bore': 0.1111111111111111,
#   'was': 0.2222222222222222},
#  ('hussein', 'was'): {'buried': 0.5, 'hanged': 0.5},
#  ('was', 'buried'): {'in': 0.3333333333333333,
#   'today': 0.3333333333333333,
#   'with': 0.3333333333333333},
#  ('buried', 'in'): {'the': 1.0},
#  ('in', 'the'): {'dead': 0.0045662100456621,
#   'northwest': 0.0045662100456621,
#   'continental': 0.0045662100456621,
#   'historical': 0.0045662100456621,
#   'interim': 0.0045662100456621,
#   'unpopular': 0.0045662100456621,
#   'ocean': 0.0045662100456621,
#   'boldest': 0.0045662100456621,
#   'peace': 0.0045662100456621,
#   'schools': 0.0045662100456621,
#   'intestine': 0.0045662100456621,
#   'volatile': 0.0045662100456621,
#   'protaliban': 0.0045662100456621,
#   'abduction': 0.0045662100456621,
#   'philippines': 0.0045662100456621,
#   'cashforhonours': 0.0045662100456621,
#   'car': 0.0045662100456621,
#   'invasion': 0.0045662100456621,
#   'coming': 0.0045662100456621,
#   'snow': 0.0045662100456621,
#   'season': 0.0045662100456621,
#   'afternoon': 0.0045662100456621,
#   'year': 0.0045662100456621,
#   'human': 0.0045662100456621,
#   'embattled': 0.0045662100456621,
#   'last': 0.0045662100456621,
#   'brain': 0.0045662100456621,
#   'light': 0.0045662100456621,
#   'search': 0.0045662100456621,
#   'english': 0.0045662100456621,
#   'gruelling': 0.0045662100456621,
#   'central': 0.0045662100456621,
#   'event': 0.0045662100456621,
#   'political': 0.0045662100456621,
#   'cultural': 0.0045662100456621,
#   'wa': 0.0045662100456621,
#   'popularity': 0.0045662100456621,
#   'military': 0.0045662100456621,
#   'shaukat': 0.0045662100456621,
#   'ruling': 0.0045662100456621,
#   'longawaited': 0.0045662100456621,
#   'rain': 0.0045662100456621,
#   'final': 0.0045662100456621,
#   'communist': 0.0045662100456621,
#   'case': 0.0045662100456621,
#   'history': 0.0045662100456621,
#   'solomon': 0.0045662100456621,
#   'far': 0.0045662100456621,
#   'fifth': 0.0045662100456621,
#   'himalayas': 0.0045662100456621,
#   'swimming': 0.0045662100456621,
#   'killings': 0.0045662100456621,
#   'east': 0.0045662100456621,
#   'virginia': 0.0045662100456621,
#   'worst': 0.0045662100456621,
#   'steppe': 0.0045662100456621,
#   'opening': 0.0045662100456621,
#   'ram': 0.0045662100456621,
#   'strifetorn': 0.0045662100456621,
#   'evening': 0.0045662100456621,
#   'second': 0.0045662100456621,
#   'adhamiyah': 0.0045662100456621,
#   'nations': 0.0045662100456621,
#   'kidnapping': 0.0045662100456621,
#   'judicial': 0.0045662100456621,
#   'th': 0.0045662100456621,
#   'hollywood': 0.0045662100456621,
#   'third': 0.0045662100456621,
#   'nepali': 0.0045662100456621,
#   'bay': 0.0045662100456621,
#   'usled': 0.0045662100456621,
#   'pakistani': 0.0045662100456621,
#   'internets': 0.0045662100456621,
#   'cuban': 0.0045662100456621,
#   'armybacked': 0.0045662100456621,
#   'pakistan': 0.0045662100456621,
#   'crossfire': 0.0045662100456621,
#   'mohave': 0.0045662100456621,
#   'treasury': 0.0045662100456621,
#   'house': 0.0045662100456621,
#   'survey': 0.0045662100456621,
#   'centre': 0.0045662100456621,
#   'white': 0.0045662100456621,
#   'complex': 0.0045662100456621,
#   'lal': 0.0045662100456621,
#   'dock': 0.0045662100456621,
#   'phone': 0.0045662100456621,
#   'fourth': 0.0045662100456621,
#   'basement': 0.0045662100456621,
#   'village': 0.0045662100456621,
#   'war': 0.0045662100456621,
#   'most': 0.0045662100456621,
#   'swat': 0.0045662100456621,
#   'murder': 0.0045662100456621,
#   'middle': 0.0045662100456621,
#   'dream': 0.0045662100456621,
#   'parliamentary': 0.0045662100456621,
#   'l': 0.0045662100456621,
#   'biggest': 0.0045662100456621,
#   'harry': 0.0045662100456621,
#   'southwestern': 0.0045662100456621,
#   'apple': 0.0045662100456621,
#   'cabin': 0.0045662100456621,
#   'workplac': 0.0045662100456621,
#   'murky': 0.0045662100456621,
#   'netherlands': 0.0045662100456621,
#   'heat': 0.0045662100456621,
#   'f': 0.0045662100456621,
#   'australian': 0.0045662100456621,
#   'remote': 0.0045662100456621,
#   'nick': 0.0045662100456621,
#   'cv': 0.0045662100456621,
#   'diplomatic': 0.0045662100456621,
#   'office': 0.0045662100456621,
#   'parking': 0.0045662100456621,
#   'gym': 0.0045662100456621,
#   'uniform': 0.0045662100456621,
#   'bronx': 0.0045662100456621,
#   'maldives': 0.0045662100456621,
#   'new': 0.0091324200913242,
#   'northern': 0.0091324200913242,
#   'west': 0.0091324200913242,
#   'south': 0.0091324200913242,
#   'southern': 0.0091324200913242,
#   'world': 0.0091324200913242,
#   'latest': 0.0091324200913242,
#   'north': 0.0091324200913242,
#   'iraqi': 0.0091324200913242,
#   'northwestern': 0.0091324200913242,
#   'gaza': 0.0091324200913242,
#   'port': 0.0091324200913242,
#   's': 0.0091324200913242,
#   'united': 0.0091324200913242,
#   'past': 0.0136986301369863,
#   'islands': 0.0136986301369863,
#   'deadliest': 0.0136986301369863,
#   'gulf': 0.0136986301369863,
#   'first': 0.0136986301369863,
#   'himalayan': 0.0136986301369863,
#   'countrys': 0.0136986301369863,
#   'heart': 0.0136986301369863,
#   'country': 0.0182648401826484,
#   'terai': 0.0182648401826484,
#   'uk': 0.0182648401826484,
#   'city': 0.0273972602739726,
#   'supreme': 0.0365296803652968,
#   'us': 0.045662100456621,
#   'capital': 0.045662100456621},
#  ('the', 'dead'): {'of': 0.5, 'man': 0.5},
#  ('dead', 'of'): {'night': 1.0},
#  ('of', 'night'): {'in': 1.0},
#  ('night', 'in'): {'his': 1.0},
#  ('in', 'his'): {'state': 0.125,
#   'labour': 0.125,
#   'new': 0.125,
#   'final': 0.125,
#   'own': 0.125,
#   'hybrid': 0.125,
#   'home': 0.25},
#  ('his', 'home'): {'village': 0.5, 'country': 0.5},
#  ('home', 'village'): {'in': 1.0},
#  ('village', 'in'): {'northern': 0.25,
#   'southern': 0.25,
#   'the': 0.25,
#   'punjab': 0.25},
#  ('in', 'northern'): {'iraq': 0.16666666666666666,
#   'england': 0.16666666666666666,
#   'pakistan': 0.16666666666666666,
#   'italy': 0.16666666666666666,
#   'sri': 0.3333333333333333},
#  ('northern', 'iraq'): {'after': 1.0},
#  ('iraq', 'after'): {'his': 0.3333333333333333,
#   'an': 0.3333333333333333,
#   'military': 0.3333333333333333},
#  ('after', 'his'): {'body': 0.14285714285714285,
#   'brother': 0.14285714285714285,
#   'arrest': 0.14285714285714285,
#   'telephone': 0.14285714285714285,
#   'fathers': 0.14285714285714285,
#   'meeting': 0.14285714285714285,
#   'return': 0.14285714285714285},
#  ('his', 'body'): {'was': 1.0},
#  ('body', 'was'): {'washed': 0.5, 'f': 0.5},
#  ('was', 'washed'): {'and': 1.0},
#  ('washed', 'and'): {'covered': 1.0},
#  ('and', 'covered'): {'in': 1.0},
#  ('covered', 'in'): {'a': 1.0},
#  ('in', 'a'): {'white': 0.006896551724137931,
#   'damage': 0.006896551724137931,
#   'dozen': 0.006896551724137931,
#   'more': 0.006896551724137931,
#   'collection': 0.006896551724137931,
#   'bus': 0.006896551724137931,
#   'slinky': 0.006896551724137931,
#   'battle': 0.006896551724137931,
#   'busy': 0.006896551724137931,
#   'firearms': 0.006896551724137931,
#   'mainly': 0.006896551724137931,
#   'fortnight': 0.006896551724137931,
#   'deal': 0.006896551724137931,
#   'tattoo': 0.006896551724137931,
#   'flap': 0.006896551724137931,
#   'businessclass': 0.006896551724137931,
#   'rare': 0.006896551724137931,
#   'motorcade': 0.006896551724137931,
#   'number': 0.006896551724137931,
#   'poker': 0.006896551724137931,
#   'week': 0.006896551724137931,
#   'millio': 0.006896551724137931,
#   'house': 0.006896551724137931,
#   'formidable': 0.006896551724137931,
#   'dramatic': 0.006896551724137931,
#   'scottish': 0.006896551724137931,
#   'coalition': 0.006896551724137931,
#   'northwestern': 0.006896551724137931,
#   'torrent': 0.006896551724137931,
#   'magazine': 0.006896551724137931,
#   'move': 0.006896551724137931,
#   'defeat': 0.006896551724137931,
#   'remote': 0.006896551724137931,
#   'solo': 0.006896551724137931,
#   'fresh': 0.006896551724137931,
#   'picture': 0.006896551724137931,
#   'planet': 0.006896551724137931,
#   'brazen': 0.006896551724137931,
#   'widening': 0.006896551724137931,
#   'runoff': 0.006896551724137931,
#   'memorial': 0.006896551724137931,
#   'parking': 0.006896551724137931,
#   'slip': 0.006896551724137931,
#   'landmark': 0.006896551724137931,
#   'davidandgoliath': 0.006896551724137931,
#   'border': 0.006896551724137931,
#   'courthouse': 0.006896551724137931,
#   'paternity': 0.006896551724137931,
#   'us': 0.006896551724137931,
#   'new': 0.006896551724137931,
#   'siberian': 0.006896551724137931,
#   'blast': 0.006896551724137931,
#   'film': 0.006896551724137931,
#   'nearby': 0.006896551724137931,
#   'growing': 0.006896551724137931,
#   'strapless': 0.006896551724137931,
#   'deadly': 0.006896551724137931,
#   'country': 0.006896551724137931,
#   'sheriffs': 0.006896551724137931,
#   'leading': 0.006896551724137931,
#   'london': 0.006896551724137931,
#   'socalled': 0.006896551724137931,
#   'critical': 0.006896551724137931,
#   'j': 0.006896551724137931,
#   'vehicle': 0.006896551724137931,
#   'resettlement': 0.006896551724137931,
#   'presiden': 0.006896551724137931,
#   'few': 0.006896551724137931,
#   'welsh': 0.006896551724137931,
#   'newspaper': 0.006896551724137931,
#   'mosque': 0.006896551724137931,
#   'jittery': 0.006896551724137931,
#   'burqa': 0.006896551724137931,
#   'radical': 0.006896551724137931,
#   'brash': 0.006896551724137931,
#   'predawn': 0.006896551724137931,
#   'minimum': 0.006896551724137931,
#   'thunderstorm': 0.006896551724137931,
#   'key': 0.006896551724137931,
#   'surge': 0.006896551724137931,
#   'historic': 0.006896551724137931,
#   'barbaric': 0.006896551724137931,
#   'safe': 0.006896551724137931,
#   'love': 0.006896551724137931,
#   'computer': 0.006896551724137931,
#   'submerged': 0.006896551724137931,
#   'lawless': 0.006896551724137931,
#   'submersible': 0.006896551724137931,
#   'repo': 0.006896551724137931,
#   'longexpected': 0.006896551724137931,
#   'blow': 0.006896551724137931,
#   'satisfactory': 0.006896551724137931,
#   'murde': 0.006896551724137931,
#   'vote': 0.006896551724137931,
#   'decision': 0.006896551724137931,
#   'direct': 0.006896551724137931,
#   'futile': 0.006896551724137931,
#   'ceremony': 0.006896551724137931,
#   'feud': 0.006896551724137931,
#   'u': 0.006896551724137931,
#   'car': 0.006896551724137931,
#   'boost': 0.006896551724137931,
#   'provincial': 0.006896551724137931,
#   'portuguese': 0.006896551724137931,
#   'rental': 0.006896551724137931,
#   'string': 0.006896551724137931,
#   'case': 0.006896551724137931,
#   'suicide': 0.006896551724137931,
#   'militantinfested': 0.006896551724137931,
#   'foreign': 0.006896551724137931,
#   'queue': 0.006896551724137931,
#   'lethal': 0.006896551724137931,
#   'group': 0.006896551724137931,
#   'peaceful': 0.006896551724137931,
#   'video': 0.013793103448275862,
#   'historical': 0.013793103448275862,
#   'series': 0.013793103448275862,
#   'major': 0.020689655172413793,
#   'campaign': 0.020689655172413793,
#   'statement': 0.020689655172413793,
#   'surprise': 0.020689655172413793,
#   'month': 0.020689655172413793,
#   'pakistani': 0.027586206896551724,
#   'bid': 0.041379310344827586},
#  ('a', 'white'): {'shroud': 0.3333333333333333,
#   'house': 0.3333333333333333,
#   'background': 0.3333333333333333},
#  ('white', 'shroud'): {'in': 1.0},
#  ('shroud', 'in'): {'observance': 1.0},
#  ('in', 'observance'): {'of': 1.0},
#  ('observance', 'of'): {'muslim': 1.0},
#  ('of', 'muslim'): {'rite': 1.0},
#  ('muslim', 'rite'): {'by': 1.0},
#  ('rite', 'by'): {'a': 1.0},
#  ('by', 'a'): {'small': 0.04,
#   'thick': 0.04,
#   'huge': 0.04,
#   'yearold': 0.04,
#   'bloody': 0.04,
#   'tamil': 0.04,
#   'comfortable': 0.04,
#   'gunman': 0.04,
#   'storm': 0.04,
#   'court': 0.04,
#   'frenzy': 0.04,
#   'lone': 0.04,
#   'message': 0.04,
#   'lot': 0.04,
#   'suicide': 0.04,
#   'machinists': 0.04,
#   'new': 0.04,
#   'pickup': 0.04,
#   'series': 0.04,
#   'shanghai': 0.04,
#   'car': 0.04,
#   'security': 0.04,
#   'us': 0.12},
#  ('a', 'small'): {'farming': 0.16666666666666666,
#   'beard': 0.16666666666666666,
#   'but': 0.16666666666666666,
#   'town': 0.16666666666666666,
#   'group': 0.3333333333333333},
#  ('small', 'group'): {'of': 1.0},
#  ('group', 'of'): {'fellow': 0.06666666666666667,
#   'prominent': 0.06666666666666667,
#   'astronauts': 0.06666666666666667,
#   'indigenous': 0.06666666666666667,
#   'german': 0.06666666666666667,
#   'english': 0.06666666666666667,
#   'european': 0.06666666666666667,
#   'wine': 0.06666666666666667,
#   'hardline': 0.06666666666666667,
#   'advisers': 0.06666666666666667,
#   'maoist': 0.06666666666666667,
#   'shocked': 0.06666666666666667,
#   'saudi': 0.06666666666666667,
#   'eight': 0.13333333333333333},
#  ('of', 'fellow'): {'tribesmen': 1.0},
#  ('reuters', 'the'): {'british': 1.0},
#  ('the', 'british'): {'tv': 0.05555555555555555,
#   'medical': 0.05555555555555555,
#   'superspys': 0.05555555555555555,
#   'premier': 0.05555555555555555,
#   'capitals': 0.05555555555555555,
#   'attorneygeneral': 0.05555555555555555,
#   'navy': 0.05555555555555555,
#   'embassy': 0.05555555555555555,
#   'military': 0.05555555555555555,
#   'acto': 0.05555555555555555,
#   'ambassador': 0.05555555555555555,
#   'throne': 0.1111111111111111,
#   'sailors': 0.1111111111111111,
#   'government': 0.16666666666666666},
#  ('british', 'government'): {'will': 0.3333333333333333,
#   'would': 0.3333333333333333,
#   'was': 0.3333333333333333},
#  ('government', 'will'): {'raise': 0.5, 'submit': 0.5},
#  ('will', 'raise'): {'the': 1.0},
#  ('raise', 'the'): {'minimum': 1.0},
#  ('the', 'minimum'): {'age': 1.0},
#  ('minimum', 'age'): {'for': 1.0},
#  ('age', 'for'): {'buying': 1.0},
#  ('for', 'buying'): {'tobacco': 1.0},
#  ('buying', 'tobacco'): {'to': 1.0},
#  ('tobacco', 'to'): {'from': 1.0},
#  ('to', 'from'): {'in': 1.0},
#  ('from', 'in'): {'an': 1.0},
#  ('in', 'an'): {'unusually': 0.02702702702702703,
#   'ostensibly': 0.02702702702702703,
#   'early': 0.02702702702702703,
#   'emotional': 0.02702702702702703,
#   'investigation': 0.02702702702702703,
#   'election': 0.02702702702702703,
#   'unsupervised': 0.02702702702702703,
#   'ob': 0.02702702702702703,
#   'unprecedented': 0.02702702702702703,
#   'interim': 0.02702702702702703,
#   'apartment': 0.02702702702702703,
#   'internet': 0.02702702702702703,
#   'apparent': 0.02702702702702703,
#   'at': 0.02702702702702703,
#   'entrance': 0.02702702702702703,
#   'amsterdam': 0.02702702702702703,
#   'impoverished': 0.02702702702702703,
#   'ongoing': 0.02702702702702703,
#   'armed': 0.02702702702702703,
#   'attack': 0.05405405405405406,
#   'effort': 0.05405405405405406,
#   'islamabad': 0.05405405405405406,
#   'army': 0.05405405405405406,
#   'attempt': 0.13513513513513514,
#   'interview': 0.13513513513513514},
#  ('an', 'attempt'): {'t': 0.14285714285714285, 'to': 0.8571428571428571},
#  ('attempt', 'to'): {'reduce': 0.1111111111111111,
#   'disrupt': 0.1111111111111111,
#   'win': 0.1111111111111111,
#   'pile': 0.1111111111111111,
#   'i': 0.1111111111111111,
#   'reconstruct': 0.1111111111111111,
#   'impose': 0.1111111111111111,
#   'seal': 0.1111111111111111,
#   'boost': 0.1111111111111111},
#  ('to', 'reduce'): {'smoking': 0.5, 'catch': 0.5},
#  ('reduce', 'smoking'): {'by': 1.0},
#  ('smoking', 'by'): {'teenagers': 1.0},
#  ('the', 'bangladesh'): {'election': 0.2,
#   'president': 0.2,
#   'bank': 0.2,
#   'government': 0.4},
#  ('bangladesh', 'election'): {'commission': 1.0},
#  ('election', 'commission'): {'today': 0.09090909090909091,
#   'official': 0.09090909090909091,
#   'resigned': 0.09090909090909091,
#   'of': 0.09090909090909091,
#   'announced': 0.09090909090909091,
#   'engaged': 0.09090909090909091,
#   'is': 0.09090909090909091,
#   'has': 0.09090909090909091,
#   'accepted': 0.09090909090909091,
#   'said': 0.18181818181818182},
#  ('commission', 'today'): {'dismissed': 1.0},
#  ('today', 'dismissed'): {'an': 0.5, 'allegations': 0.5},
#  ('dismissed', 'an'): {'appeal': 1.0},
#  ('an', 'appeal'): {'by': 0.3333333333333333,
#   'against': 0.3333333333333333,
#   'court': 0.3333333333333333},
#  ('appeal', 'by'): {'former': 1.0},
#  ('by', 'former'): {'military': 0.25, 'chie': 0.25, 'prime': 0.5},
#  ('former', 'military'): {'dictator': 0.5, 'ruler': 0.5},
#  ('military', 'dictator'): {'hussain': 1.0},
#  ('dictator', 'hussain'): {'muhammad': 1.0},
#  ('hussain', 'muhammad'): {'ershad': 1.0},
#  ('muhammad', 'ershad'): {'to': 1.0},
#  ('ershad', 'to'): {'run': 1.0},
#  ('to', 'run'): {'in': 0.5, 'as': 0.5},
#  ('run', 'in'): {'january': 1.0},
#  ('in', 'january'): {'national': 0.5, 'citing': 0.5},
#  ('january', 'national'): {'elections': 1.0},
#  ('it', 'would'): {'launch': 0.0625,
#   'withdraw': 0.0625,
#   'continue': 0.0625,
#   'make': 0.0625,
#   'release': 0.0625,
#   'announce': 0.0625,
#   'tantamount': 0.0625,
#   'grant': 0.0625,
#   'consider': 0.0625,
#   'take': 0.0625,
#   'offer': 0.0625,
#   'not': 0.125,
#   'be': 0.1875},
#  ('would', 'be'): {'awesome': 0.08333333333333333,
#   'given': 0.08333333333333333,
#   'happy': 0.08333333333333333,
#   'an': 0.08333333333333333,
#   'the': 0.08333333333333333,
#   'no': 0.08333333333333333,
#   'unable': 0.08333333333333333,
#   'likely': 0.08333333333333333,
#   'prime': 0.08333333333333333,
#   'killed': 0.08333333333333333,
#   'prosecuted': 0.08333333333333333,
#   'worked': 0.08333333333333333},
#  ('be', 'awesome'): {'if': 1.0},
#  ('awesome', 'if'): {'tomkat': 1.0},
#  ('if', 'tomkat'): {'and': 1.0},
#  ('tomkat', 'and'): {'other': 1.0},
#  ('and', 'other'): {'combined': 0.06666666666666667,
#   'areas': 0.06666666666666667,
#   'concessions': 0.06666666666666667,
#   'countries': 0.06666666666666667,
#   'addictive': 0.06666666666666667,
#   'engineers': 0.06666666666666667,
#   'drugs': 0.06666666666666667,
#   'political': 0.06666666666666667,
#   'attacks': 0.06666666666666667,
#   'resul': 0.06666666666666667,
#   'astronauts': 0.06666666666666667,
#   'products': 0.06666666666666667,
#   'humanrights': 0.06666666666666667,
#   'crimes': 0.13333333333333333},
#  ('other', 'combined'): {'nicknames': 1.0},
#  ('combined', 'nicknames'): {'for': 1.0},
#  ('nicknames', 'for'): {'celebrity': 1.0},
#  ('for', 'celebrity'): {'couples': 1.0},
#  ('celebrity', 'couples'): {'went': 1.0},
#  ('couples', 'went'): {'missing': 1.0},
#  ('went', 'missing'): {'in': 1.0},
#  ('missing', 'in'): {'the': 0.5, 'iraq': 0.5},
#  ('the', 'new'): {'year': 0.1,
#   'pcs': 0.1,
#   'interim': 0.1,
#   'secondary': 0.1,
#   'orleans': 0.1,
#   'breed': 0.1,
#   'york': 0.4},
#  ('new', 'year'): {'a': 0.5, 'message': 0.5},
#  ('year', 'a'): {'michigan': 1.0},
#  ('a', 'michigan'): {'university': 0.5, 'prison': 0.5},
#  ('michigan', 'university'): {'said': 1.0},
#  ('eight', 'bombs'): {'exploded': 1.0},
#  ('bombs', 'exploded'): {'across': 1.0},
#  ('exploded', 'across'): {'bangkok': 1.0},
#  ('across', 'bangkok'): {'on': 1.0},
#  ('bangkok', 'on'): {'new': 1.0},
#  ('on', 'new'): {'years': 1.0},
#  ('new', 'years'): {'eve': 1.0},
#  ('years', 'eve'): {'killing': 0.5, 'party': 0.5},
#  ('eve', 'killing'): {'two': 1.0},
#  ('killing', 'two'): {'people': 0.5, 'in': 0.5},
#  ('two', 'people'): {'and': 1.0},
#  ('people', 'and'): {'shutting': 0.08333333333333333,
#   'raided': 0.08333333333333333,
#   'damaging': 0.08333333333333333,
#   'i': 0.08333333333333333,
#   'trapping': 0.08333333333333333,
#   'burying': 0.08333333333333333,
#   'injuring': 0.16666666666666666,
#   'wounded': 0.3333333333333333},
#  ('and', 'shutting'): {'down': 1.0},
#  ('shutting', 'down'): {'pu': 0.3333333333333333,
#   'an': 0.3333333333333333,
#   'public': 0.3333333333333333},
#  ('the', 'government'): {'says': 0.038461538461538464,
#   'supply': 0.038461538461538464,
#   'has': 0.038461538461538464,
#   'is': 0.038461538461538464,
#   'some': 0.038461538461538464,
#   'two': 0.038461538461538464,
#   'that': 0.038461538461538464,
#   'was': 0.038461538461538464,
#   'for': 0.038461538461538464,
#   'but': 0.038461538461538464,
#   'of': 0.038461538461538464,
#   'sought': 0.038461538461538464,
#   'to': 0.038461538461538464,
#   'accusing': 0.038461538461538464,
#   'sent': 0.038461538461538464,
#   'doubled': 0.038461538461538464,
#   'said': 0.07692307692307693,
#   'today': 0.11538461538461539,
#   'and': 0.15384615384615385},
#  ('government', 'says'): {'around': 1.0},
#  ('says', 'around'): {'per': 1.0},
#  ('around', 'per'): {'cent': 1.0},
#  ('per', 'cent'): {'compared': 0.047619047619047616,
#   'from': 0.047619047619047616,
#   'in': 0.047619047619047616,
#   'rise': 0.047619047619047616,
#   'to': 0.047619047619047616,
#   'said': 0.047619047619047616,
#   'while': 0.047619047619047616,
#   'next': 0.047619047619047616,
#   'increase': 0.047619047619047616,
#   'protection': 0.047619047619047616,
#   'sure': 0.047619047619047616,
#   'at': 0.09523809523809523,
#   'of': 0.2857142857142857},
#  ('cent', 'of'): {'britons': 0.16666666666666666,
#   'candidates': 0.16666666666666666,
#   'beggars': 0.16666666666666666,
#   'all': 0.16666666666666666,
#   'the': 0.3333333333333333},
#  ('of', 'britons'): {'between': 0.5, 'regularly': 0.5},
#  ('britons', 'between'): {'and': 1.0},
#  ('between', 'and'): {'smoke': 0.5, 'supportive': 0.5},
#  ('and', 'smoke'): {'and': 0.5, 'rose': 0.5},
#  ('smoke', 'and'): {'it': 1.0},
#  ('and', 'it'): {'is': 0.25, 'may': 0.25, 'should': 0.25, 'happened': 0.25},
#  ('it', 'is'): {'determined': 0.05555555555555555,
#   'taken': 0.05555555555555555,
#   'not': 0.05555555555555555,
#   'investigating': 0.05555555555555555,
#   'in': 0.05555555555555555,
#   'an': 0.05555555555555555,
#   'his': 0.05555555555555555,
#   'quite': 0.05555555555555555,
#   'interrogating': 0.05555555555555555,
#   'dissolved': 0.05555555555555555,
#   'combining': 0.05555555555555555,
#   'too': 0.05555555555555555,
#   'no': 0.05555555555555555,
#   'promoting': 0.05555555555555555,
#   'like': 0.05555555555555555,
#   'hard': 0.05555555555555555,
#   'a': 0.1111111111111111},
#  ('is', 'determined'): {'to': 1.0},
#  ('determined', 'to'): {'check': 1.0},
#  ('to', 'check'): {'it': 1.0},
#  ('the', 'change'): {'will': 1.0},
#  ('change', 'will'): {'bring': 1.0},
#  ('will', 'bring'): {'england': 1.0},
#  ('bring', 'england'): {'and': 1.0},
#  ('england', 'and'): {'wales': 1.0},
#  ('and', 'wales'): {'in': 1.0},
#  ('wales', 'in'): {'line': 1.0},
#  ('in', 'line'): {'with': 0.4, 'to': 0.6},
#  ('line', 'with'): {'several': 0.5, 'wes': 0.5},
#  ('with', 'several'): {'european': 0.5, 'elvis': 0.5},
#  ('several', 'european'): {'countries': 1.0},
#  ('european', 'countries'): {'and': 1.0},
#  ('countries', 'and'): {'the': 1.0},
#  ('and', 'the'): {'la': 0.019230769230769232,
#   'liberal': 0.019230769230769232,
#   'p': 0.019230769230769232,
#   'buildup': 0.019230769230769232,
#   'maoist': 0.019230769230769232,
#   'husband': 0.019230769230769232,
#   'largest': 0.019230769230769232,
#   'outgoing': 0.019230769230769232,
#   'chennailondon': 0.019230769230769232,
#   'sale': 0.019230769230769232,
#   'holocaust': 0.019230769230769232,
#   'troubled': 0.019230769230769232,
#   'un': 0.019230769230769232,
#   'opposition': 0.019230769230769232,
#   'mob': 0.019230769230769232,
#   'ne': 0.019230769230769232,
#   'role': 0.019230769230769232,
#   'form': 0.019230769230769232,
#   'al': 0.019230769230769232,
#   'undoing': 0.019230769230769232,
#   'compos': 0.019230769230769232,
#   'supreme': 0.019230769230769232,
#   'national': 0.019230769230769232,
#   'secular': 0.019230769230769232,
#   'ogre': 0.019230769230769232,
#   'first': 0.019230769230769232,
#   'cia': 0.019230769230769232,
#   'jamia': 0.019230769230769232,
#   'two': 0.019230769230769232,
#   'society': 0.019230769230769232,
#   'duke': 0.019230769230769232,
#   'farming': 0.019230769230769232,
#   'public': 0.019230769230769232,
#   'army': 0.019230769230769232,
#   'pakistanis': 0.019230769230769232,
#   'energyrich': 0.019230769230769232,
#   'mausoleums': 0.019230769230769232,
#   'mans': 0.019230769230769232,
#   'death': 0.019230769230769232,
#   'right': 0.019230769230769232,
#   'madhesi': 0.019230769230769232,
#   'family': 0.019230769230769232,
#   'vote': 0.019230769230769232,
#   'crew': 0.019230769230769232,
#   'us': 0.038461538461538464,
#   'west': 0.038461538461538464,
#   'eu': 0.057692307692307696},
#  ('the', 'us'): {'a': 0.010416666666666666,
#   'tonight': 0.010416666666666666,
#   'could': 0.010416666666666666,
#   'columnist': 0.010416666666666666,
#   'administration': 0.010416666666666666,
#   'mostly': 0.010416666666666666,
#   'contribution': 0.010416666666666666,
#   'in': 0.010416666666666666,
#   'but': 0.010416666666666666,
#   'rocker': 0.010416666666666666,
#   'mission': 0.010416666666666666,
#   'house': 0.010416666666666666,
#   'rate': 0.010416666666666666,
#   'department': 0.010416666666666666,
#   'against': 0.010416666666666666,
#   'fifth': 0.010416666666666666,
#   'fears': 0.010416666666666666,
#   'ban': 0.010416666666666666,
#   'urged': 0.010416666666666666,
#   'this': 0.010416666666666666,
#   'the': 0.010416666666666666,
#   'fought': 0.010416666666666666,
#   'over': 0.010416666666666666,
#   'by': 0.010416666666666666,
#   'food': 0.010416666666666666,
#   'will': 0.010416666666666666,
#   'assisted': 0.010416666666666666,
#   'wants': 0.010416666666666666,
#   'push': 0.010416666666666666,
#   'have': 0.010416666666666666,
#   'after': 0.010416666666666666,
#   'renewed': 0.010416666666666666,
#   'must': 0.010416666666666666,
#   'atomic': 0.010416666666666666,
#   'sent': 0.010416666666666666,
#   'saying': 0.010416666666666666,
#   'to': 0.010416666666666666,
#   'with': 0.010416666666666666,
#   'denounced': 0.010416666666666666,
#   'embassy': 0.020833333333333332,
#   'government': 0.020833333333333332,
#   'has': 0.020833333333333332,
#   'said': 0.020833333333333332,
#   'navy': 0.020833333333333332,
#   'had': 0.020833333333333332,
#   'that': 0.020833333333333332,
#   'would': 0.020833333333333332,
#   'congress': 0.020833333333333332,
#   'for': 0.020833333333333332,
#   'is': 0.020833333333333332,
#   'offered': 0.020833333333333332,
#   'space': 0.020833333333333332,
#   'supreme': 0.03125,
#   'senate': 0.03125,
#   'today': 0.03125,
#   'state': 0.03125,
#   'and': 0.0625,
#   'military': 0.10416666666666667},
#  ('us', 'military'): {'death': 0.058823529411764705,
#   'helicopter': 0.058823529411764705,
#   'believes': 0.058823529411764705,
#   'in': 0.058823529411764705,
#   'tribunal': 0.058823529411764705,
#   'outpost': 0.058823529411764705,
#   'is': 0.058823529411764705,
#   'effort': 0.058823529411764705,
#   'plan': 0.058823529411764705,
#   'prison': 0.058823529411764705,
#   'court': 0.058823529411764705,
#   'judges': 0.058823529411764705,
#   'said': 0.29411764705882354},
#  ('military', 'death'): {'toll': 1.0},
#  ('death', 'toll'): {'rose': 0.3333333333333333, 'in': 0.6666666666666666},
#  ('toll', 'in'): {'iraq': 0.5, 'britains': 0.5},
#  ('in', 'iraq'): {'are': 0.07142857142857142,
#   'he': 0.07142857142857142,
#   'and': 0.07142857142857142,
#   'moves': 0.07142857142857142,
#   'a': 0.07142857142857142,
#   'whom': 0.07142857142857142,
#   'but': 0.07142857142857142,
#   'after': 0.14285714285714285,
#   'has': 0.21428571428571427},
#  ('iraq', 'has'): {'reached': 0.25,
#   'modified': 0.25,
#   'won': 0.25,
#   'offered': 0.25},
#  ('has', 'reached'): {'an': 1.0},
#  ('reached', 'an'): {'unwelcome': 1.0},
#  ('an', 'unwelcome'): {'milestone': 1.0},
#  ('unwelcome', 'milestone'): {'for': 1.0},
#  ('milestone', 'for'): {'president': 1.0},
#  ('for', 'president'): {'george': 0.3333333333333333,
#   'pervez': 0.6666666666666666},
#  ('president', 'george'): {'bush': 0.02564102564102564,
#   'w': 0.9743589743589743},
#  ('george', 'w'): {'bushs': 0.20512820512820512, 'bush': 0.7692307692307693},
#  ('w', 'bush'): {'says': 0.03333333333333333,
#   'urged': 0.03333333333333333,
#   'over': 0.03333333333333333,
#   'for': 0.03333333333333333,
#   'was': 0.03333333333333333,
#   'brought': 0.03333333333333333,
#   'receiving': 0.03333333333333333,
#   'has': 0.03333333333333333,
#   'reaffirmed': 0.03333333333333333,
#   'and': 0.03333333333333333,
#   'today': 0.03333333333333333,
#   'tou': 0.03333333333333333,
#   'welcomed': 0.03333333333333333,
#   'dines': 0.03333333333333333,
#   'he': 0.03333333333333333,
#   'will': 0.06666666666666667,
#   'yesterday': 0.06666666666666667,
#   'a': 0.06666666666666667,
#   'who': 0.1,
#   'said': 0.13333333333333333},
#  ('bush', 'who'): {'is': 0.3333333333333333,
#   'sometimes': 0.3333333333333333,
#   'alluded': 0.3333333333333333},
#  ('who', 'is'): {'searching': 0.09090909090909091,
#   'considering': 0.09090909090909091,
#   'third': 0.09090909090909091,
#   'mar': 0.09090909090909091,
#   'ruling': 0.09090909090909091,
#   'now': 0.09090909090909091,
#   'terminally': 0.09090909090909091,
#   'holed': 0.09090909090909091,
#   'sought': 0.09090909090909091,
#   'wanted': 0.18181818181818182},
#  ('is', 'searching'): {'for': 1.0},
#  ('searching', 'for'): {'a': 1.0},
#  ('for', 'a'): {'way': 0.021739130434782608,
#   'series': 0.021739130434782608,
#   'plane': 0.021739130434782608,
#   'brief': 0.021739130434782608,
#   'meeting': 0.021739130434782608,
#   'daughter': 0.021739130434782608,
#   'time': 0.021739130434782608,
#   'peaceful': 0.021739130434782608,
#   'spacewalk': 0.021739130434782608,
#   'space': 0.021739130434782608,
#   'world': 0.021739130434782608,
#   'panel': 0.021739130434782608,
#   'forbidden': 0.021739130434782608,
#   'fundraising': 0.021739130434782608,
#   'twoweek': 0.021739130434782608,
#   'crucial': 0.021739130434782608,
#   'student': 0.021739130434782608,
#   'faux': 0.021739130434782608,
#   'media': 0.021739130434782608,
#   'court': 0.021739130434782608,
#   'walk': 0.021739130434782608,
#   'few': 0.021739130434782608,
#   'man': 0.021739130434782608,
#   'new': 0.021739130434782608,
#   'controversial': 0.021739130434782608,
#   'woody': 0.021739130434782608,
#   'condemned': 0.021739130434782608,
#   'mascara': 0.021739130434782608,
#   'nasa': 0.021739130434782608,
#   'suicide': 0.021739130434782608,
#   'ban': 0.021739130434782608,
#   'hearttoheart': 0.021739130434782608,
#   'vandal': 0.021739130434782608,
#   'tricky': 0.021739130434782608,
#   'total': 0.043478260869565216,
#   'year': 0.043478260869565216,
#   'full': 0.043478260869565216,
#   'fifth': 0.043478260869565216,
#   'second': 0.08695652173913043},
#  ('a', 'way'): {'to': 1.0},
#  ('way', 'to'): {'turn': 0.16666666666666666,
#   'improve': 0.16666666666666666,
#   'transfer': 0.16666666666666666,
#   'elections': 0.16666666666666666,
#   'the': 0.3333333333333333},
#  ('to', 'turn'): {'around': 0.5, 'nepal': 0.5},
#  ('turn', 'around'): {'the': 1.0},
#  ('around', 'the'): {'unpopular': 0.16666666666666666,
#   'mercedesbenz': 0.16666666666666666,
#   'historical': 0.16666666666666666,
#   'notorious': 0.16666666666666666,
#   'world': 0.3333333333333333},
#  ('the', 'unpopular'): {'war': 1.0},
#  ('unpopular', 'war'): {'even': 0.5},
#  ('war', 'even'): {'if': 1.0},
#  ('even', 'if'): {'it': 0.5, 'terrorism': 0.5},
#  ('if', 'it'): {'means': 0.25, 'failed': 0.25, 'should': 0.25, 'does': 0.25},
#  ('it', 'means'): {'sending': 1.0},
#  ('means', 'sending'): {'more': 1.0},
#  ('sending', 'more'): {'troops': 0.5, 'than': 0.5},
#  ('thailands', 'militaryinstalled'): {'government': 1.0},
#  ('militaryinstalled', 'government'): {'blamed': 1.0},
#  ('government', 'blamed'): {'former': 1.0},
#  ('blamed', 'former'): {'politicians': 1.0},
#  ('former', 'politicians'): {'today': 1.0},
#  ('politicians', 'today'): {'for': 1.0},
#  ('today', 'for'): {'hitting': 0.08333333333333333,
#   'insulting': 0.08333333333333333,
#   'their': 0.08333333333333333,
#   'nearly': 0.08333333333333333,
#   'help': 0.08333333333333333,
#   'a': 0.5833333333333334},
#  ('a', 'series'): {'of': 1.0},
#  ('series', 'of'): {'bombs': 0.08333333333333333,
#   'incidents': 0.08333333333333333,
#   'fresh': 0.08333333333333333,
#   'wars': 0.08333333333333333,
#   'letters': 0.08333333333333333,
#   'letter': 0.08333333333333333,
#   'measures': 0.08333333333333333,
#   'attacks': 0.08333333333333333,
#   'aftershocks': 0.08333333333333333,
#   'product': 0.08333333333333333,
#   'three': 0.16666666666666666},
#  ('of', 'bombs'): {'that': 1.0},
#  ('bombs', 'that'): {'killed': 1.0},
#  ('that', 'killed'): {'three': 0.125,
#   'commuters': 0.125,
#   'one': 0.125,
#   'about': 0.125,
#   'people': 0.125,
#   'at': 0.375},
#  ('killed', 'three'): {'people': 0.5, 'chinese': 0.5},
#  ('three', 'people'): {'in': 1.0},
#  ('people', 'in'): {'bangkok': 0.043478260869565216,
#   'south': 0.043478260869565216,
#   'parliament': 0.043478260869565216,
#   'three': 0.043478260869565216,
#   'algerias': 0.043478260869565216,
#   'beijing': 0.043478260869565216,
#   'baghdad': 0.043478260869565216,
#   'eastern': 0.043478260869565216,
#   'bangladesh': 0.043478260869565216,
#   'parts': 0.043478260869565216,
#   'four': 0.043478260869565216,
#   'kathmandu': 0.043478260869565216,
#   'myanmar': 0.043478260869565216,
#   'pakistan': 0.08695652173913043,
#   'a': 0.13043478260869565,
#   'the': 0.21739130434782608},
#  ('in', 'bangkok'): {'wounded': 1.0},
#  ('bangkok', 'wounded'): {'including': 1.0},
#  ('wounded', 'including'): {'nine': 1.0},
#  ('including', 'nine'): {'foreigners': 1.0},
#  ('rescue', 'teams'): {'scrambled': 0.5, 'and': 0.5},
#  ('teams', 'scrambled'): {'to': 1.0},
#  ('scrambled', 'to'): {'determine': 0.25, 'contain': 0.25, 'find': 0.5},
#  ('to', 'find'): {'alternatives': 0.1111111111111111,
#   'room': 0.1111111111111111,
#   'any': 0.1111111111111111,
#   'survivors': 0.1111111111111111,
#   'her': 0.1111111111111111,
#   'a': 0.2222222222222222,
#   'out': 0.2222222222222222},
#  ('find', 'a'): {'missing': 0.3333333333333333,
#   'kenya': 0.3333333333333333,
#   'bra': 0.3333333333333333},
#  ('a', 'missing'): {'boeing': 1.0},
#  ('missing', 'boeing'): {'passenger': 1.0},
#  ('boeing', 'passenger'): {'plane': 1.0},
#  ('passenger', 'plane'): {'with': 0.3333333333333333,
#   'made': 0.3333333333333333,
#   'which': 0.3333333333333333},
#  ('plane', 'with'): {'more': 0.5, 'people': 0.5},
#  ('with', 'more'): {'than': 1.0},
#  ('more', 'than'): {'refugees': 0.02,
#   'threequarters': 0.02,
#   'kg': 0.02,
#   'displaced': 0.02,
#   'seven': 0.02,
#   'twothirds': 0.02,
#   'ha': 0.02,
#   'president': 0.02,
#   'students': 0.02,
#   'police': 0.02,
#   'suspects': 0.02,
#   'turkish': 0.02,
#   'other': 0.02,
#   'an': 0.02,
#   'yards': 0.02,
#   'children': 0.02,
#   'workers': 0.02,
#   'one': 0.02,
#   'peoples': 0.02,
#   'afghan': 0.02,
#   'international': 0.02,
#   'three': 0.02,
#   'suspected': 0.02,
#   'and': 0.02,
#   'additional': 0.04,
#   'years': 0.04,
#   'twice': 0.04,
#   'million': 0.04,
#   'half': 0.04,
#   'new': 0.04,
#   'billion': 0.04,
#   'people': 0.08,
#   'a': 0.16},
#  ('than', 'people'): {'on': 0.25, 'and': 0.25, 'most': 0.25, 'in': 0.25},
#  ('people', 'on'): {'the': 0.125, 'a': 0.125, 'board': 0.625},
#  ('on', 'board'): {'that': 0.14285714285714285,
#   'remained': 0.14285714285714285,
#   'have': 0.14285714285714285,
#   'but': 0.14285714285714285,
#   'survived': 0.14285714285714285,
#   'including': 0.14285714285714285,
#   'flights': 0.14285714285714285},
#  ('board', 'that'): {'sent': 1.0},
#  ('that', 'sent'): {'out': 1.0},
#  ('sent', 'out'): {'a': 1.0},
#  ('out', 'a'): {'distress': 0.2,
#   'prize': 0.2,
#   'million': 0.2,
#   'pakistani': 0.2,
#   'procession': 0.2},
#  ('a', 'distress'): {'signal': 1.0},
#  ('distress', 'signal'): {'while': 1.0},
#  ('signal', 'while'): {'flying': 1.0},
#  ('while', 'flying'): {'in': 1.0},
#  ('flying', 'in'): {'bad': 1.0},
#  ('in', 'bad'): {'weather': 1.0},
#  ('bad', 'weather'): {'over': 0.5, 'forced': 0.5},
#  ('weather', 'over'): {'indone': 1.0},
#  ('theres', 'a'): {'royal': 1.0},
#  ('a', 'royal'): {'stink': 0.5, 'air': 0.5},
#  ('royal', 'stink'): {'on': 1.0},
#  ('stink', 'on'): {'the': 1.0},
#  ('on', 'the'): {'israeljordan': 0.013157894736842105,
#   'gallows': 0.013157894736842105,
#   'export': 0.013157894736842105,
#   'due': 0.013157894736842105,
#   'annual': 0.013157894736842105,
#   'shah': 0.013157894736842105,
#   'execution': 0.013157894736842105,
#   'cause': 0.013157894736842105,
#   'media': 0.013157894736842105,
#   'street': 0.013157894736842105,
#   'hubble': 0.013157894736842105,
#   'movement': 0.013157894736842105,
#   'trains': 0.013157894736842105,
#   'us': 0.013157894736842105,
#   'world': 0.013157894736842105,
#   'korean': 0.013157894736842105,
#   'norths': 0.013157894736842105,
#   'false': 0.013157894736842105,
#   'islamic': 0.013157894736842105,
#   'dutch': 0.013157894736842105,
#   'question': 0.013157894736842105,
#   'platform': 0.013157894736842105,
#   'religious': 0.013157894736842105,
#   'border': 0.013157894736842105,
#   'hollywood': 0.013157894736842105,
#   'talibans': 0.013157894736842105,
#   'trade': 0.013157894736842105,
#   'plane': 0.013157894736842105,
#   'need': 0.013157894736842105,
#   'fate': 0.013157894736842105,
#   'holocaust': 0.013157894736842105,
#   'return': 0.013157894736842105,
#   'website': 0.013157894736842105,
#   'eve': 0.013157894736842105,
#   'beloved': 0.013157894736842105,
#   'rampage': 0.013157894736842105,
#   'campaign': 0.013157894736842105,
#   'sunset': 0.013157894736842105,
#   'roof': 0.013157894736842105,
#   'west': 0.013157894736842105,
#   'militarys': 0.013157894736842105,
#   'front': 0.013157894736842105,
#   'twin': 0.013157894736842105,
#   'international': 0.013157894736842105,
#   'planet': 0.013157894736842105,
#   'ultraslim': 0.013157894736842105,
#   'anniversary': 0.013157894736842105,
#   'workers': 0.013157894736842105,
#   'dome': 0.013157894736842105,
#   'move': 0.013157894736842105,
#   'lal': 0.013157894736842105,
#   'relati': 0.013157894736842105,
#   'quran': 0.013157894736842105,
#   'big': 0.013157894736842105,
#   'forum': 0.013157894736842105,
#   'ruling': 0.013157894736842105,
#   'japanese': 0.013157894736842105,
#   'winning': 0.013157894736842105,
#   'charred': 0.013157894736842105,
#   'dhaka': 0.013157894736842105,
#   'set': 0.013157894736842105,
#   'wrong': 0.013157894736842105,
#   'day': 0.013157894736842105,
#   'army': 0.013157894736842105,
#   'road': 0.013157894736842105,
#   'edge': 0.013157894736842105,
#   'third': 0.02631578947368421,
#   'verge': 0.02631578947368421,
#   'internet': 0.039473684210526314},
#  ('the', 'israeljordan'): {'border': 1.0},
#  ('while', 'in'): {'us': 0.5, 'india': 0.5},
#  ('in', 'us'): {'custody': 0.25, 'education': 0.25, 'history': 0.5},
#  ('us', 'custody'): {'former': 1.0},
#  ('custody', 'former'): {'iraqi': 1.0},
#  ('former', 'iraqi'): {'president': 1.0},
#  ('iraqi', 'president'): {'jalal': 0.3333333333333333,
#   'saddam': 0.6666666666666666},
#  ('president', 'saddam'): {'hussein': 1.0},
#  ('hussein', 'smoked'): {'cigars': 1.0},
#  ('smoked', 'cigars'): {'watered': 1.0},
#  ('cigars', 'watered'): {'a': 1.0},
#  ('watered', 'a'): {'few': 1.0},
#  ('a', 'few'): {'weeds': 0.14285714285714285,
#   'words': 0.14285714285714285,
#   'extra': 0.14285714285714285,
#   'months': 0.2857142857142857,
#   'hours': 0.2857142857142857},
#  ('few', 'weeds'): {'and': 1.0},
#  ('weeds', 'and'): {'reminisced': 1.0},
#  ('and', 'reminisced'): {'about': 1.0},
#  ('reminisced', 'about'): {'happy': 1.0},
#  ('about', 'happy'): {'times': 1.0},
#  ('happy', 'times'): {'when': 1.0},
#  ('times', 'when'): {'his': 0.5, 'he': 0.5},
#  ('when', 'his'): {'children': 0.5, 'term': 0.5},
#  ('his', 'children'): {'were': 0.5, 'but': 0.5},
#  ('children', 'were'): {'young': 0.5, 'killed': 0.5},
#  ('were', 'young'): {'a': 1.0},
#  ('young', 'a'): {'nurse': 1.0},
#  ('a', 'nurse'): {'who': 1.0},
#  ('nurse', 'who'): {'cared': 1.0},
#  ('us', 'pop'): {'star': 1.0},
#  ('pop', 'star'): {'kylie': 0.14285714285714285,
#   'britney': 0.2857142857142857,
#   'christina': 0.5714285714285714},
#  ('star', 'christina'): {'aguilera': 1.0},
#  ('christina', 'aguilera'): {'to': 0.16666666666666666,
#   'at': 0.3333333333333333,
#   'performs': 0.5},
#  ('aguilera', 'performs'): {'during': 0.3333333333333333,
#   'at': 0.6666666666666666},
#  ('performs', 'during'): {'a': 1.0},
#  ('during', 'a'): {'new': 0.05555555555555555,
#   'friendly': 0.05555555555555555,
#   'longhaul': 0.05555555555555555,
#   'promotional': 0.05555555555555555,
#   'meeting': 0.05555555555555555,
#   'buddhist': 0.05555555555555555,
#   'performance': 0.05555555555555555,
#   'weeklong': 0.05555555555555555,
#   'dispute': 0.05555555555555555,
#   'last': 0.05555555555555555,
#   'raid': 0.05555555555555555,
#   'concert': 0.16666666666666666,
#   'protest': 0.2222222222222222},
#  ('a', 'new'): {'years': 0.030303030303030304,
#   'caretaker': 0.030303030303030304,
#   'regulation': 0.030303030303030304,
#   'york': 0.030303030303030304,
#   'line': 0.030303030303030304,
#   'production': 0.030303030303030304,
#   'challenge': 0.030303030303030304,
#   'test': 0.030303030303030304,
#   'style': 0.030303030303030304,
#   'arms': 0.030303030303030304,
#   'antimissile': 0.030303030303030304,
#   'class': 0.030303030303030304,
#   'nuclear': 0.030303030303030304,
#   'term': 0.030303030303030304,
#   'officially': 0.030303030303030304,
#   'theory': 0.030303030303030304,
#   'deadline': 0.030303030303030304,
#   'concept': 0.030303030303030304,
#   'armydrafted': 0.030303030303030304,
#   'sports': 0.030303030303030304,
#   'tape': 0.030303030303030304,
#   'fiveyear': 0.030303030303030304,
#   'crackdown': 0.030303030303030304,
#   'interim': 0.06060606060606061,
#   'phase': 0.06060606060606061,
#   'study': 0.09090909090909091,
#   'government': 0.09090909090909091},
#  ('eve', 'party'): {'in': 1.0},
#  ('party', 'in'): {'new': 0.25, 'hollywood': 0.25, 'los': 0.5},
#  ('in', 'new'): {'orleans': 0.045454545454545456,
#   'jersey': 0.09090909090909091,
#   'delhi': 0.13636363636363635,
#   'york': 0.7272727272727273},
#  ('new', 'york'): {'who': 0.03225806451612903,
#   'afp': 0.03225806451612903,
#   'cabbie': 0.03225806451612903,
#   'and': 0.03225806451612903,
#   'times': 0.03225806451612903,
#   'is': 0.03225806451612903,
#   'reuters': 0.03225806451612903,
#   'offer': 0.03225806451612903,
#   'stock': 0.03225806451612903,
#   'mayor': 0.03225806451612903,
#   'high': 0.03225806451612903,
#   'police': 0.03225806451612903,
#   'for': 0.03225806451612903,
#   'premiere': 0.06451612903225806,
#   'city': 0.12903225806451613,
#   'on': 0.16129032258064516,
#   'ap': 0.1935483870967742},
#  ('britons', 'flying'): {'to': 1.0},
#  ('flying', 'to'): {'america': 1.0},
#  ('to', 'america'): {'could': 0.3333333333333333, 'are': 0.3333333333333333},
#  ('america', 'could'): {'have': 0.5, 'be': 0.5},
#  ('could', 'have'): {'their': 1.0},
#  ('have', 'their'): {'credit': 1.0},
#  ('their', 'credit'): {'card': 1.0},
#  ('credit', 'card'): {'and': 1.0},
#  ('card', 'and'): {'email': 1.0},
#  ('and', 'email'): {'accounts': 1.0},
#  ('email', 'accounts'): {'inspected': 1.0},
#  ('accounts', 'inspected'): {'by': 1.0},
#  ('inspected', 'by'): {'the': 1.0},
#  ('by', 'the'): {'vatican': 0.02127659574468085,
#   'powerful': 0.02127659574468085,
#   'national': 0.02127659574468085,
#   'house': 0.02127659574468085,
#   'police': 0.02127659574468085,
#   'singer': 0.02127659574468085,
#   'un': 0.02127659574468085,
#   'exodus': 0.02127659574468085,
#   'british': 0.02127659574468085,
#   'pentagons': 0.02127659574468085,
#   'electoral': 0.02127659574468085,
#   'supreme': 0.02127659574468085,
#   'fact': 0.02127659574468085,
#   'prime': 0.02127659574468085,
#   'worst': 0.02127659574468085,
#   'army': 0.02127659574468085,
#   'shootings': 0.02127659574468085,
#   'interim': 0.02127659574468085,
#   'sitting': 0.02127659574468085,
#   'separatists': 0.02127659574468085,
#   'ltte': 0.02127659574468085,
#   'cia': 0.02127659574468085,
#   'countrys': 0.02127659574468085,
#   'same': 0.02127659574468085,
#   'third': 0.02127659574468085,
#   'year': 0.02127659574468085,
#   'booming': 0.02127659574468085,
#   'bourgeoisie': 0.02127659574468085,
#   'monarch': 0.02127659574468085,
#   'pakistani': 0.02127659574468085,
#   'mujahideen': 0.02127659574468085,
#   'arrest': 0.02127659574468085,
#   'mohajir': 0.02127659574468085,
#   'high': 0.02127659574468085,
#   'taliban': 0.02127659574468085,
#   'iraqi': 0.02127659574468085,
#   'death': 0.02127659574468085,
#   'unbacked': 0.02127659574468085,
#   'government': 0.02127659574468085,
#   'us': 0.0425531914893617,
#   'maoists': 0.0425531914893617,
#   'end': 0.0851063829787234},
#  ('coming', 'soon'): {'to': 1.0},
#  ('soon', 'to'): {'german': 0.3333333333333333,
#   'hear': 0.3333333333333333,
#   'say': 0.3333333333333333},
#  ('to', 'german'): {'cinemas': 1.0},
#  ('german', 'cinemas'): {'a': 1.0},
#  ('cinemas', 'a'): {'demoralised': 1.0},
#  ('a', 'demoralised'): {'drugaddled': 1.0},
#  ('demoralised', 'drugaddled'): {'adolf': 1.0},
#  ('drugaddled', 'adolf'): {'hitler': 1.0},
#  ('adolf', 'hitler'): {'who': 0.3333333333333333,
#   'from': 0.3333333333333333,
#   'will': 0.3333333333333333},
#  ('hitler', 'who'): {'plays': 1.0},
#  ('who', 'plays'): {'with': 1.0},
#  ('plays', 'with'): {'a': 1.0},
#  ('with', 'a'): {'toy': 0.027777777777777776,
#   'lot': 0.027777777777777776,
#   'stingray': 0.027777777777777776,
#   'polished': 0.027777777777777776,
#   'pledge': 0.027777777777777776,
#   'gold': 0.027777777777777776,
#   'shotgun': 0.027777777777777776,
#   'series': 0.027777777777777776,
#   'bogus': 0.027777777777777776,
#   'worldview': 0.027777777777777776,
#   'range': 0.027777777777777776,
#   'professor': 0.027777777777777776,
#   'subtle': 0.027777777777777776,
#   'click': 0.027777777777777776,
#   'russianus': 0.027777777777777776,
#   'cake': 0.027777777777777776,
#   'warning': 0.027777777777777776,
#   'request': 0.027777777777777776,
#   'diagnosis': 0.027777777777777776,
#   'dark': 0.027777777777777776,
#   'palestinian': 0.027777777777777776,
#   'two': 0.027777777777777776,
#   'knighthood': 0.027777777777777776,
#   'perfect': 0.027777777777777776,
#   'bloodline': 0.027777777777777776,
#   'required': 0.027777777777777776,
#   'flaming': 0.027777777777777776,
#   'radical': 0.027777777777777776,
#   'crush': 0.027777777777777776,
#   'woman': 0.027777777777777776,
#   'plenary': 0.027777777777777776,
#   'new': 0.027777777777777776,
#   'british': 0.05555555555555555},
#  ('a', 'toy'): {'battles': 0.5, 'shop': 0.5},
#  ('hanging', 'was'): {'nearly': 0.5, 'conducted': 0.5},
#  ('was', 'nearly'): {'halted': 1.0},
#  ('thousands', 'of'): {'sunnis': 0.03125,
#   'protesters': 0.03125,
#   'doctors': 0.03125,
#   'japanese': 0.03125,
#   'british': 0.03125,
#   'tamil': 0.03125,
#   'shias': 0.03125,
#   'turkeys': 0.03125,
#   'additional': 0.03125,
#   'job': 0.03125,
#   'survivors': 0.03125,
#   'homeless': 0.03125,
#   'opposition': 0.03125,
#   'sombre': 0.03125,
#   'supporters': 0.03125,
#   'cheering': 0.03125,
#   'civilians': 0.03125,
#   'junior': 0.03125,
#   'years': 0.03125,
#   'patients': 0.03125,
#   'lawyers': 0.03125,
#   'government': 0.03125,
#   'harry': 0.03125,
#   'loyalists': 0.03125,
#   'greeks': 0.03125,
#   'mourners': 0.0625,
#   'people': 0.0625,
#   'troops': 0.09375},
#  ('of', 'sunnis'): {'vented': 1.0},
#  ('sunnis', 'vented'): {'their': 1.0},
#  ('vented', 'their'): {'anger': 1.0},
#  ('their', 'anger'): {'today': 0.5, 'and': 0.5},
#  ('anger', 'today'): {'over': 1.0},
#  ('today', 'over'): {'saddam': 0.16666666666666666,
#   'the': 0.16666666666666666,
#   'who': 0.16666666666666666,
#   'remarks': 0.16666666666666666,
#   'moscows': 0.16666666666666666,
#   'his': 0.16666666666666666},
#  ('over', 'saddam'): {'husseins': 1.0},
#  ('saddam', 'husseins'): {'codefendants': 0.16666666666666666,
#   'former': 0.16666666666666666,
#   'eldest': 0.16666666666666666,
#   'cousin': 0.16666666666666666,
#   'execution': 0.3333333333333333},
#  ('husseins', 'execution'): {'as': 0.5, 'should': 0.5},
#  ('execution', 'as'): {'the': 1.0},
#  ('as', 'the'): {'iraqi': 0.03225806451612903,
#   'c': 0.03225806451612903,
#   'sri': 0.03225806451612903,
#   'terai': 0.03225806451612903,
#   'monarch': 0.03225806451612903,
#   'popes': 0.03225806451612903,
#   'storm': 0.03225806451612903,
#   'acting': 0.03225806451612903,
#   'thousands': 0.03225806451612903,
#   'carri': 0.03225806451612903,
#   'government': 0.03225806451612903,
#   'vanguard': 0.03225806451612903,
#   'first': 0.03225806451612903,
#   'armourplated': 0.03225806451612903,
#   'biggest': 0.03225806451612903,
#   'city': 0.03225806451612903,
#   'mosque': 0.03225806451612903,
#   'norm': 0.03225806451612903,
#   'game': 0.03225806451612903,
#   'water': 0.03225806451612903,
#   'price': 0.03225806451612903,
#   'orbiter': 0.03225806451612903,
#   'militarybacked': 0.03225806451612903,
#   'cabinet': 0.03225806451612903,
#   'national': 0.03225806451612903,
#   'sept': 0.03225806451612903,
#   'maoists': 0.03225806451612903,
#   'former': 0.03225806451612903,
#   'election': 0.03225806451612903,
#   'countrys': 0.06451612903225806},
#  ('the', 'iraqi'): {'parliament': 0.16666666666666666,
#   'holy': 0.16666666666666666,
#   'government': 0.3333333333333333,
#   'leader': 0.3333333333333333},
#  ('iraqi', 'government'): {'promised': 0.3333333333333333,
#   'officials': 0.3333333333333333,
#   'on': 0.3333333333333333},
#  ('government', 'promised'): {'an': 1.0},
#  ('promised', 'an'): {'investigation': 1.0},
#  ('an', 'investigation'): {'after': 0.2, 'tied': 0.2, 'into': 0.6},
#  ('investigation', 'into'): {'illicitly': 0.25,
#   'alleged': 0.25,
#   'allegations': 0.25,
#   'the': 0.25},
#  ('into', 'illicitly'): {'filmed': 1.0},
#  ('illicitly', 'filmed'): {'footage': 1.0},
#  ('filmed', 'footage'): {'of': 1.0},
#  ('footage', 'of'): {'shia': 0.5, 'john': 0.5},
#  ('of', 'shia'): {'officials': 1.0},
#  ('shia', 'officials'): {'taunting': 1.0},
#  ('officials', 'taunting'): {'him': 1.0},
#  ('taunting', 'him'): {'on': 1.0},
#  ('him', 'on'): {'the': 1.0},
#  ('the', 'fate'): {'of': 1.0},
# ...
#  ('in', 'los'): {'angeles': 1.0},
#  ('los', 'angeles'): {'for': 0.037037037037037035,
#   'hair': 0.037037037037037035,
#   'were': 0.037037037037037035,
#   'fashion': 0.037037037037037035,
#   'police': 0.037037037037037035,
#   'times': 0.037037037037037035,
#   'park': 0.037037037037037035,
#   'reuters': 0.037037037037037035,
#   'international': 0.037037037037037035,
#   'ap': 0.25925925925925924,
#   'on': 0.37037037037037035},
#  ('angeles', 'on'): {'sunday': 0.1,
#   'wednesday': 0.2,
#   'saturday': 0.2,
#   'thursday': 0.2,
#   'tuesday': 0.3},
#  ('on', 'wednesday'): {'tony': 0.0625,
#   'he': 0.0625,
#   'afp': 0.1875,
#   'reuters': 0.3125,
#   'ap': 0.375},
#  ('the', 'plight'): {'of': 1.0},
#  ('plight', 'of'): {'former': 1.0},
#  ('of', 'former'): {'slaves': 0.07142857142857142,
#   'army': 0.07142857142857142,
#   'beatle': 0.07142857142857142,
#   'bangladesh': 0.07142857142857142,
#   'us': 0.07142857142857142,
#   'pakistani': 0.07142857142857142,
#   'president': 0.21428571428571427,
#   'prime': 0.35714285714285715},
#  ('former', 'slaves'): {'who': 1.0},
#  ('slaves', 'who'): {'were': 1.0},
#  ('who', 'were'): {'freed': 0.14285714285714285,
#   'affected': 0.14285714285714285,
#   'guilty': 0.14285714285714285,
#   'detained': 0.14285714285714285,
#   'holed': 0.14285714285714285,
#   'getting': 0.14285714285714285,
#   'killed': 0.14285714285714285},
#  ('were', 'freed'): {'from': 0.25, 'without': 0.25, 'today': 0.5},
#  ('freed', 'from'): {'bondage': 0.5, 'a': 0.5},
#  ('from', 'bondage'): {'in': 1.0},
#  ('bondage', 'in'): {'nepal': 1.0},
#  ('in', 'nepal'): {'six': 0.08333333333333333,
#   'have': 0.08333333333333333,
#   'today': 0.08333333333333333,
#   'suffered': 0.08333333333333333,
#   'and': 0.08333333333333333,
#   'seeking': 0.08333333333333333,
#   'so': 0.08333333333333333,
#   'continue': 0.08333333333333333,
#   'are': 0.16666666666666666},
#  ('nepal', 'six'): {'years': 1.0},
#  ('six', 'years'): {'ago': 1.0},
#  ('years', 'ago'): {'is': 0.2, 'in': 0.2, 'reported': 0.2, 'or': 0.2},
#  ('ago', 'is'): {'so': 1.0},
#  ('is', 'so'): {'desperate': 0.5, 'pampered': 0.5},
#  ('so', 'desperate'): {'that': 1.0},
#  ('taliban', 'chief'): {'mullah': 1.0},
#  ('chief', 'mullah'): {'mohammad': 1.0},
#  ('mullah', 'mohammad'): {'omar': 1.0},
#  ('mohammad', 'omar'): {'has': 1.0},
#  ('omar', 'has'): {'added': 1.0},
#  ('has', 'added'): {'to': 1.0},
#  ('added', 'to'): {'the': 1.0},
#  ('to', 'the'): {'mystery': 0.010752688172043012,
#   'number': 0.010752688172043012,
#   'presidential': 0.010752688172043012,
#   'public': 0.010752688172043012,
#   'creation': 0.010752688172043012,
#   'rank': 0.010752688172043012,
#   'pr': 0.010752688172043012,
#   'throne': 0.010752688172043012,
#   'people': 0.010752688172043012,
#   'monarch': 0.010752688172043012,
#   'holy': 0.010752688172043012,
#   'iraq': 0.010752688172043012,
#   'gates': 0.010752688172043012,
#   'assassination': 0.010752688172043012,
#   'streets': 0.010752688172043012,
#   'palestinian': 0.010752688172043012,
#   'gallows': 0.010752688172043012,
#   'formation': 0.010752688172043012,
#   'culture': 0.010752688172043012,
#   'fashion': 0.010752688172043012,
#   'main': 0.010752688172043012,
#   'management': 0.010752688172043012,
#   'liberation': 0.010752688172043012,
#   'iraqi': 0.010752688172043012,
#   'political': 0.010752688172043012,
#   'town': 0.010752688172043012,
#   'names': 0.010752688172043012,
#   'schools': 0.010752688172043012,
#   'gunman': 0.010752688172043012,
#   'campaign': 0.010752688172043012,
#   'sound': 0.010752688172043012,
#   'strategy': 0.010752688172043012,
#   'controversial': 0.010752688172043012,
#   'capital': 0.010752688172043012,
#   'maoist': 0.010752688172043012,
#   'flowerpots': 0.010752688172043012,
#   'countrys': 0.010752688172043012,
#   'september': 0.010752688172043012,
#   'security': 0.010752688172043012,
#   'cancellation': 0.010752688172043012,
#   'bloody': 0.010752688172043012,
#   'interior': 0.010752688172043012,
#   'soviet': 0.010752688172043012,
#   'intelligence': 0.010752688172043012,
#   'lal': 0.010752688172043012,
#   'police': 0.010752688172043012,
#   'fury': 0.010752688172043012,
#   'midnight': 0.010752688172043012,
#   'generals': 0.010752688172043012,
#   'pleas': 0.010752688172043012,
#   'governmen': 0.010752688172043012,
#   'militarybacked': 0.010752688172043012,
#   'eye': 0.010752688172043012,
#   'general': 0.010752688172043012,
#   'customer': 0.010752688172043012,
#   'ruling': 0.010752688172043012,
#   'table': 0.010752688172043012,
#   'monarchy': 0.010752688172043012,
#   'presidency': 0.010752688172043012,
#   'authorities': 0.010752688172043012,
#   'former': 0.010752688172043012,
#   'shwedagon': 0.010752688172043012,
#   'ethnic': 0.021505376344086023,
#   'interim': 0.021505376344086023,
#   'british': 0.021505376344086023,
#   'himalayan': 0.021505376344086023,
#   'ppp': 0.021505376344086023,
#   'supreme': 0.021505376344086023,
#   'un': 0.021505376344086023,
#   'media': 0.021505376344086023,
#   'internet': 0.021505376344086023,
#   'stage': 0.021505376344086023,
#   'international': 0.021505376344086023,
#   'constituent': 0.03225806451612903,
#   'us': 0.043010752688172046},
#  ('the', 'mystery'): {'over': 1.0},
#  ('mystery', 'over'): {'osama': 0.3333333333333333,
#   'what': 0.3333333333333333,
#   'whether': 0.3333333333333333},
#  ('over', 'osama'): {'bin': 1.0},
#  ('osama', 'bin'): {'ladens': 0.18181818181818182,
#   'laden': 0.8181818181818182},
#  ('bin', 'laden'): {'saying': 0.1111111111111111,
#   'and': 0.1111111111111111,
#   'who': 0.1111111111111111,
#   'was': 0.1111111111111111,
#   'in': 0.1111111111111111,
#   'praises': 0.1111111111111111,
#   'defied': 0.1111111111111111,
#   'has': 0.2222222222222222},
#  ('laden', 'saying'): {'he': 1.0},
#  ('saying', 'he'): {'has': 0.25, 'had': 0.25, 'would': 0.25, 'and': 0.25},
#  ('he', 'has'): {'changed': 0.2,
#   'distanced': 0.2,
#   'clarified': 0.2,
#   'not': 0.4},
#  ('we', 'have'): {'no': 0.5, 'to': 0.5},
#  ('have', 'no'): {'alternative': 1.0},
#  ('no', 'alternative'): {'to': 1.0},
#  ('alternative', 'to'): {'holding': 1.0},
#  ('to', 'holding'): {'the': 1.0},
#  ('holding', 'the'): {'elections': 1.0},
#  ('the', 'elections'): {'on': 1.0},
#  ('elections', 'on'): {'the': 0.5, 'corruption': 0.5},
#  ('the', 'due'): {'date': 1.0},
#  ('due', 'date'): {'an': 1.0},
#  ('date', 'an'): {'election': 1.0},
#  ('an', 'election'): {'commission': 0.5, 'the': 0.5},
#  ('commission', 'official'): {'said': 1.0},
#  ('two', 'other'): {'parties': 0.5, 'people': 0.5},
#  ('other', 'parties'): {'announced': 1.0},
#  ('parties', 'announced'): {'a': 1.0},
#  ('announced', 'a'): {'boycott': 0.3333333333333333,
#   'series': 0.6666666666666666},
#  ('a', 'boycott'): {'the': 1.0},
#  ('boycott', 'the'): {'jatiya': 1.0},
#  ('the', 'jatiya'): {'party': 1.0},
#  ('jatiya', 'party'): {'of': 0.5, 'and': 0.5},
#  ('party', 'of'): {'subve': 0.25, 'former': 0.75},
#  ('former', 'army'): {'chief': 0.25, 'ruler': 0.75},
#  ('army', 'ruler'): {'hossain': 1.0},
#  ('ruler', 'hossain'): {'mohammad': 1.0},
#  ('hossain', 'mohammad'): {'ershad': 1.0},
#  ('mohammad', 'ershad'): {'and': 0.2, 'banned': 0.2, 'was': 0.2, 'today': 0.4},
#  ('ershad', 'and'): {'the': 1.0},
#  ('the', 'liberal'): {'democratic': 1.0},
#  ('liberal', 'democratic'): {'party': 1.0},
#  ('democratic', 'party'): {'of': 0.5, 'presidential': 0.5},
#  ('former', 'president'): {'aqm': 0.2,
#   'sheikh': 0.2,
#   'boris': 0.2,
#   'and': 0.2,
#   'who': 0.2},
#  ('president', 'aqm'): {'badruddoza': 1.0},
#  ('aqm', 'badruddoza'): {'chowdhury': 1.0},
#  ('bush', 'said'): {'yesterday': 0.25, 'in': 0.25, 'today': 0.5},
#  ('said', 'yesterday'): {'after': 0.07142857142857142,
#   'it': 0.07142857142857142,
#   'she': 0.07142857142857142,
#   'in': 0.07142857142857142,
#   'a': 0.07142857142857142,
#   'as': 0.07142857142857142,
#   'that': 0.14285714285714285,
#   'the': 0.14285714285714285},
#  ('yesterday', 'that'): {'saddam': 0.14285714285714285,
#   'it': 0.14285714285714285,
#   'hackers': 0.14285714285714285,
#   'president': 0.14285714285714285,
#   'the': 0.14285714285714285,
#   'they': 0.2857142857142857},
#  ('that', 'saddam'): {'husseins': 1.0},
#  ('execution', 'should'): {'have': 1.0},
#  ('should', 'have'): {'been': 0.5, 'trusted': 0.5},
#  ('have', 'been'): {'carried': 0.04,
#   'found': 0.04,
#   'criticised': 0.04,
#   'arrested': 0.04,
#   'lifting': 0.04,
#   'kil': 0.04,
#   'inspired': 0.04,
#   'killed': 0.04,
#   'started': 0.04,
#   'identified': 0.04,
#   'told': 0.04,
#   'sold': 0.04,
#   'dwarfed': 0.04,
#   'formally': 0.04,
#   'bobby': 0.04,
#   'forced': 0.04,
#   'so': 0.04,
#   'right': 0.04,
#   'shortlisted': 0.04,
#   'declared': 0.04,
#   'a': 0.08,
#   'charged': 0.08},
#  ('been', 'carried'): {'out': 1.0},
#  ('carried', 'out'): {'in': 0.25, 'checks': 0.25, 'the': 0.5},
#  ('out', 'in'): {'a': 1.0},
#  ('a', 'more'): {'dignified': 0.5, 'conservative': 0.5},
#  ('more', 'dignified'): {'way': 1.0},
#  ('dignified', 'way'): {'but': 1.0},
#  ('way', 'but'): {'the': 1.0},
#  ('iraqi', 'leader'): {'had': 0.5, 'said': 0.5},
#  ('leader', 'had'): {'received': 0.5, 'better': 0.5},
#  ('had', 'received'): {'justice': 0.3333333333333333,
#   'a': 0.3333333333333333,
#   'between': 0.3333333333333333},
#  ('received', 'justice'): {'which': 1.0},
#  ('justice', 'which'): {'his': 1.0},
#  ('which', 'his'): {'victims': 1.0},
#  ('his', 'victims'): {'had': 1.0},
#  ('victims', 'had'): {'not': 1.0},
#  ('egyptian', 'president'): {'hosni': 1.0},
#  ('president', 'hosni'): {'mubarak': 1.0},
#  ('hosni', 'mubarak'): {'said': 1.0},
#  ('mubarak', 'said'): {'in': 1.0},
#  ('said', 'in'): {'a': 0.375, 'an': 0.625},
#  ('an', 'interview'): {'before': 0.2, 'published': 0.4, 'that': 0.4},
#  ('interview', 'published'): {'today': 1.0},
#  ('published', 'today'): {'that': 0.2,
#   'after': 0.2,
#   'officials': 0.2,
#   'he': 0.2},
#  ('that', 'execution'): {'had': 1.0},
#  ('execution', 'had'): {'turned': 1.0},
#  ('had', 'turned'): {'deposed': 1.0},
#  ('turned', 'deposed'): {'iraqi': 1.0},
#  ('deposed', 'iraqi'): {'president': 1.0},
#  ('hussein', 'into'): {'a': 1.0},
#  ('into', 'a'): {'martyr': 0.08333333333333333,
#   'federal': 0.08333333333333333,
#   'busy': 0.08333333333333333,
#   'bomb': 0.08333333333333333,
#   'higher': 0.08333333333333333,
#   'us': 0.08333333333333333,
#   'different': 0.08333333333333333,
#   'coma': 0.08333333333333333,
#   'shia': 0.08333333333333333,
#   'plea': 0.08333333333333333,
#   'mountainside': 0.08333333333333333,
#   'crowd': 0.08333333333333333},
#  ('a', 'martyr'): {'and': 1.0},
#  ('martyr', 'and'): {'pictures': 0.5, 'three': 0.5},
#  ('and', 'pictures'): {'of': 0.5, 'sent': 0.5},
#  ('pictures', 'of'): {'the': 0.5, 'protests': 0.5},
#  ('as', 'day'): {'three': 1.0},
#  ('day', 'three'): {'dawned': 1.0},
#  ('three', 'dawned'): {'for': 1.0},
#  ('dawned', 'for'): {'shilpa': 1.0},
#  ('for', 'shilpa'): {'shetty': 1.0},
#  ('shilpa', 'shetty'): {'in': 0.5, 'made': 0.5},
#  ('shetty', 'in'): {'celebrity': 1.0},
#  ('in', 'celebrity'): {'big': 1.0},
#  ('celebrity', 'big'): {'brother': 1.0},
#  ('big', 'brother'): {'house': 1.0},
#  ('brother', 'house'): {'the': 1.0},
#  ('house', 'the'): {'telegraph': 1.0},
#  ('the', 'telegraph'): {'was': 0.5, 'that': 0.5},
#  ('telegraph', 'was'): {'besieged': 1.0},
#  ('was', 'besieged'): {'by': 1.0},
#  ('besieged', 'by'): {'calls': 0.5, 'government': 0.5},
#  ('by', 'calls'): {'today': 1.0},
#  ('calls', 'today'): {'from': 1.0},
#  ('today', 'from'): {'indian': 0.3333333333333333,
#   'a': 0.3333333333333333,
#   'the': 0.3333333333333333},
#  ('from', 'indian'): {'viewers': 1.0},
#  ('indian', 'viewers'): {'asking': 1.0},
#  ('viewers', 'asking'): {'for': 1.0},
#  ('asking', 'for'): {'help': 1.0},
#  ('for', 'help'): {'to': 0.25, 'in': 0.25, 'after': 0.25},
#  ('help', 'to'): {'ensure': 0.5, 'resolve': 0.5},
#  ('to', 'ensure'): {'the': 0.2,
#   'free': 0.2,
#   'they': 0.2,
#   'respect': 0.2,
#   'that': 0.2},
#  ('oscar', 'wilde'): {'poet': 1.0},
#  ('wilde', 'poet'): {'playwright': 1.0},
#  ('poet', 'playwright'): {'gay': 1.0},
#  ('playwright', 'gay'): {'icon': 1.0},
#  ('gay', 'icon'): {'and': 1.0},
#  ('icon', 'and'): {'deathbed': 1.0},
#  ('and', 'deathbed'): {'convert': 1.0},
#  ('deathbed', 'convert'): {'to': 1.0},
#  ('convert', 'to'): {'catholicism': 0.5, 'islam': 0.5},
#  ('to', 'catholicism'): {'has': 1.0},
#  ('catholicism', 'has'): {'been': 1.0},
#  ('has', 'been'): {'paid': 0.024390243902439025,
#   'ordered': 0.024390243902439025,
#   'destroyed': 0.024390243902439025,
#   'relieved': 0.024390243902439025,
#   'killed': 0.024390243902439025,
#   'questioned': 0.024390243902439025,
#   'led': 0.024390243902439025,
#   'removed': 0.024390243902439025,
#   'formally': 0.024390243902439025,
#   'trying': 0.024390243902439025,
#   'suspended': 0.024390243902439025,
#   'the': 0.024390243902439025,
#   'detected': 0.024390243902439025,
#   'victimised': 0.024390243902439025,
#   'both': 0.024390243902439025,
#   'hard': 0.024390243902439025,
#   'handed': 0.024390243902439025,
#   'so': 0.024390243902439025,
#   'cleared': 0.024390243902439025,
#   'reborn': 0.024390243902439025,
#   'possibly': 0.024390243902439025,
#   'under': 0.024390243902439025,
#   'linked': 0.024390243902439025,
#   'discovered': 0.024390243902439025,
#   'admitted': 0.024390243902439025,
#   'released': 0.024390243902439025,
#   'nominated': 0.024390243902439025,
#   'slow': 0.024390243902439025,
#   'slammed': 0.024390243902439025,
#   'accused': 0.04878048780487805,
#   'convicted': 0.04878048780487805,
#   'arrested': 0.04878048780487805,
#   'dubbed': 0.04878048780487805,
#   'called': 0.04878048780487805,
#   'shaken': 0.04878048780487805},
#  ('been', 'paid'): {'a': 0.5, 'its': 0.5},
#  ('paid', 'a'): {'rare': 0.3333333333333333,
#   'political': 0.3333333333333333,
#   'compliment': 0.3333333333333333},
#  ('a', 'rare'): {'tribute': 0.16666666666666666,
#   'suicide': 0.16666666666666666,
#   'pu': 0.16666666666666666,
#   'highlevel': 0.16666666666666666,
#   'victory': 0.16666666666666666,
#   'category': 0.16666666666666666},
#  ('rare', 'tribute'): {'by': 1.0},
#  ('tribute', 'by'): {'the': 1.0},
#  ('the', 'vatican'): {'his': 0.5, 'and': 0.5},
#  ('vatican', 'his'): {'aphorisms': 1.0},
#  ('his', 'aphorisms'): {'are': 1.0},
#  ('aphorisms', 'are'): {'quoted': 1.0},
#  ('are', 'quoted'): {'in': 1.0},
#  ('quoted', 'in'): {'a': 1.0},
#  ('a', 'collection'): {'of': 1.0},
#  ('collection', 'of'): {'maxi': 1.0},
#  ('new', 'un'): {'secretarygeneral': 0.5, 'sanctions': 0.5},
#  ('kimoon', 'will'): {'appoint': 1.0},
#  ('will', 'appoint'): {'tanzanian': 1.0},
#  ('appoint', 'tanzanian'): {'foreign': 1.0},
#  ('tanzanian', 'foreign'): {'minister': 1.0},
#  ('foreign', 'minister'): {'asharose': 0.2,
#   'tzipi': 0.2,
#   'as': 0.2,
#   'khursheed': 0.4},
#  ('minister', 'asharose'): {'migiro': 1.0},
#  ('asharose', 'migiro'): {'as': 1.0},
#  ('migiro', 'as'): {'his': 1.0},
#  ('as', 'his'): {'deputy': 0.3333333333333333,
#   'government': 0.3333333333333333,
#   'prime': 0.3333333333333333},
#  ('his', 'deputy'): {'fulfilling': 0.5},
#  ('deputy', 'fulfilling'): {'a': 1.0},
#  ('fulfilling', 'a'): {'pledge': 0.5, 'threat': 0.5},
#  ('a', 'pledge'): {'to': 1.0},
#  ('pledge', 'to'): {'name': 0.3333333333333333,
#   'end': 0.3333333333333333,
#   'free': 0.3333333333333333},
#  ('to', 'name'): {'a': 1.0},
#  ('name', 'a'): {'woman': 1.0},
#  ('a', 'woman'): {'to': 0.1111111111111111,
#   'passerby': 0.1111111111111111,
#   'half': 0.1111111111111111,
#   'has': 0.1111111111111111,
#   'whose': 0.1111111111111111,
#   'on': 0.1111111111111111,
#   'while': 0.1111111111111111,
#   'who': 0.2222222222222222},
#  ('woman', 'to'): {'the': 1.0},
#  ('the', 'number'): {'twop': 0.125, 'one': 0.125, 'of': 0.75},
#  ('number', 'twop'): {'post': 1.0},
#  ('twop', 'post'): {'un': 1.0},
#  ('bangladeshs', 'former'): {'military': 0.08333333333333333,
#   'army': 0.16666666666666666,
#   'prime': 0.75},
#  ('ershad', 'banned'): {'from': 1.0},
#  ('banned', 'from'): {'contesting': 0.3333333333333333,
#   'wearing': 0.3333333333333333,
#   'returning': 0.3333333333333333},
#  ('from', 'contesting'): {'elections': 1.0},
#  ('contesting', 'elections'): {'on': 0.3333333333333333,
#   'and': 0.3333333333333333,
#   'sa': 0.3333333333333333},
#  ('on', 'corruption'): {'charges': 0.3333333333333333,
#   'advisers': 0.3333333333333333,
#   'by': 0.3333333333333333},
#  ('corruption', 'charges'): {'has': 0.5, 'bro': 0.5},
#  ('charges', 'has'): {'been': 1.0},
#  ('been', 'ordered'): {'to': 1.0},
#  ('ordered', 'to'): {'surrender': 1.0},
#  ('to', 'surrender'): {'to': 0.3333333333333333},
#  ...}

# %%
import random
sentence_finished = False
text = ['today',
 'the']
while not sentence_finished:
    r = random.random()
    acc = .0
    for word in sent[tuple(text[-2:])].keys():
        acc += sent[tuple(text[-2:])][word]
        if acc >= r:
            text.append(word)
            break

    if text[-2:] == ['None', 'None'] or len(text) > 30:
        sentence_finished = True
    if tuple(text[-2:]) not in sent.keys():
        sent[tuple(text[-2:])] = {'None':Least_probability}
        
print (' '.join([t for t in text if t]))
# Out:
# today the british acto None None

# %% [markdown]
# Sentence Generation : Bigram

# %%
sent1 = {}
for x in dataset_model_smoothed.bigram_frequencies.keys():
    if x[0] not in sent1.keys():
        sent1[x[0]] = {}
    sent1[x[0]][x[1]] = float(dataset_model_smoothed.bigram_frequencies[(x[0],x[1])])/float(dataset_model_smoothed.unigram_frequencies[x[0]])

# %%
for x in sent1.keys():
    sent1[x] = dict(sorted(sent1[x].items(),key=lambda x: x[1]))

# %%
import random
sentence_finished = False
text = ['today', 'the']
while not sentence_finished:
    r = random.random()
    acc = .0
    if text[-1] not in sent1.keys():
        break
    for word in sent1[text[-1]].keys():
        acc += sent1[text[-1]][word]
        if acc >= r:
            text.append(word)
            break

    if text[-1] == 'None' or len(text) > 30:
        sentence_finished = True
    if text[-1] not in sent.keys():
        sent1[text[-1]] = {'None':Least_probability}
        
print (' '.join([t for t in text if t]))
# Out:
# today the data None

# %%
from nltk.lm import MLE

# %%
vocab = []
for x in Data:
    for y in x:
        if y not in vocab:
            vocab.append(y)

# %%
from nltk.util import ngrams
text_bigrams = [ngrams(sent, 2) for sent in Data]
text_unigrams = [ngrams(sent, 1) for sent in Data]
text_trigrams = [ngrams(sent, 3) for sent in Data]

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
train, vocab = padded_everygram_pipeline(2, text_unigrams)

# %%
lm = MLE(1)

# %%
lm.fit(train,vocab)
s = lm.generate(10,random_seed=0)

# %%
s

# %%
lm1 = MLE(2)

# %%
lm1.fit(train,vocab)
s1 = lm1.generate(10,random_seed=0)

# %%
s1
# Out:
# ['the',
#  'second',
#  'landing',
#  'at',
#  'nato',
#  'is',
#  'studied',
#  'differences',
#  'in',
#  'pokhara']

# %%
lm2 = MLE(3)
lm2.fit(train,vocab)
s2 = lm2.generate(10,random_seed=0)

# %%
s2
# Out:
# ['the',
#  'second',
#  'landing',
#  'at',
#  'nato',
#  'is',
#  'studied',
#  'differences',
#  'in',
#  'pokhara']

# %%
D = []
for x in Data:
    D.append(tuple(x))

# %%
D = [D]

# %%
(lm.perplexity(D),lm1.perplexity(D),lm2.perplexity(D))
# Out:
# (inf, inf, inf)
